# %% [markdown]
# # AZEEZ OLUWATOBI
#
# ## 18CJ024110
#
# ## COMPUTER ENGINEERING

# %% [markdown]
# # ANTENATAL CARE COVERAGE FOR AT LEAST ONE VISIT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics as sta

df = pd.read_csv('data.csv')

for i in range (2011, 2021, 1):
    
    x = df["COUNTRIES"]
    y = df[f"{i-1}"]
    
    s_deviation = y.std()
    
    maximum_val = y.max()
    minimum_val = y.min()
    Range_val = maximum_val - minimum_val
    
    variance_val = sta.variance(df[f"{i-1}"])

    plt.figure(figsize =(35, 20))
    plt.barh(x, y, height = 0.7)
    plt.title(f"ANNUAL PERCENTAGE OF ANTENATAL CARE VISITS IN {i-1}", fontsize = 30)
    plt.xlabel('RATE OF VISITS', fontsize = 30)
    plt.xticks(fontsize = 25)
    plt.yticks(fontsize = 20)
    plt.show()
    
    print(f'The Standard Deviation is {s_deviation}')
    print(f'The Range is {Range_val}')
    print(f'The Variance is {variance_val}')
# Out:
# The Standard Deviation is 14.487147786241161
# The Range is 54
# The Variance is 209.87745098039215
# The Standard Deviation is 16.36797585177113
# The Range is 58
# The Variance is 267.9106334841629
# The Standard Deviation is 17.596919722224317
# The Range is 63
# The Variance is 309.65158371040724
# The Standard Deviation is 18.900659169556512
# The Range is 65
# The Variance is 357.23491704374055
# The Standard Deviation is 20.265609963918013
# The Range is 67
# The Variance is 410.6949472096531
# The Standard Deviation is 20.800015590549904
# The Range is 67
# The Variance is 432.6406485671192
# The Standard Deviation is 21.479935567311816
# The Range is 69
# The Variance is 461.3876319758673
# The Standard Deviation is 22.01667919773388
# The Range is 69
# The Variance is 484.7341628959276
# The Standard Deviation is 22.048075813068667
# The Range is 68
# The Variance is 486.11764705882354
# The Standard Deviation is 22.354945532109664
# The Range is 68
# ...
